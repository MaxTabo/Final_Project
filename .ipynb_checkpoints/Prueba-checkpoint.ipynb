# %%
df3.Entity.unique()
# Out:
# array(['Africa', 'Algeria', 'Argentina', 'Asia Pacific', 'Australia',
#        'Austria', 'Azerbaijan', 'Bangladesh', 'Belarus', 'Belgium',
#        'Brazil', 'Bulgaria', 'CIS', 'Canada', 'Chile', 'China',
#        'Colombia', 'Croatia', 'Cyprus', 'Czechia', 'Denmark',
#        'Eastern Africa', 'Ecuador', 'Egypt', 'Estonia', 'Europe',
#        'European Union (27)', 'Finland', 'France', 'Germany', 'Greece',
#        'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran',
#        'Iraq', 'Ireland', 'Israel', 'Italy', 'Japan', 'Kazakhstan',
#        'Kuwait', 'Latvia', 'Lithuania', 'Luxembourg', 'Malaysia',
#        'Mexico', 'Middle Africa', 'Middle East', 'Morocco', 'Netherlands',
#        'New Zealand', 'Non-OECD', 'North Macedonia', 'Norway', 'OECD',
#        'Oman', 'Pakistan', 'Peru', 'Philippines', 'Poland', 'Portugal',
#        'Qatar', 'Romania', 'Russia', 'Saudi Arabia', 'Singapore',
#        'Slovakia', 'Slovenia', 'South Africa', 'South Korea', 'Spain',
#        'Sri Lanka', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand',
#        'Trinidad and Tobago', 'Turkey', 'Turkmenistan', 'USSR', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uzbekistan', 'Venezuela', 'Vietnam', 'Western Africa', 'World'],
#       dtype=object)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import functions

df = pd.read_csv("Data\wind-share-energy.csv")
df1 = pd.read_csv("Data\wind-generation.csv")
df2 = pd.read_csv("Data\Test IRENE.csv")
df3 = pd.read_csv("Data\solar-share-energy.csv")
df4 = pd.read_csv("Data\solar-energy-consumption-by-region.csv")
df5= pd.read_csv("Data\solar-energy-consumption.csv")
df6 = pd.read_csv("Data\share-electricity-wind.csv")
df7= pd.read_csv("Data\share-electricity-solar.csv")
df8 = pd.read_csv("Data\share-electricity-renewables.csv")
df9 = pd.read_csv("Data/share-electricity-hydro.csv")
df10 = pd.read_csv("Data/renewable-share-energy.csv")
df11 = pd.read_csv("Data\per-capita-renewables.csv")
df12 = pd.read_csv("Data\modern-renewable-prod.csv")
df13 = pd.read_csv("Data\modern-renewable-energy-consumption.csv")
df15 = pd.read_csv("Data\hydro-share-energy.csv")
df16 = pd.read_csv("Data\hydropower-consumption.csv")
df17 = pd.read_csv("Data/biofuel-production.csv")
df18 = pd.read_csv("Data/annual-percentage-change-solar.csv")
df19 = pd.read_csv("Data/annual-percentage-change-renewables.csv")
df20 = pd.read_csv("Data/annual-change-solar.csv")
df21 = pd.read_csv("Data/annual-change-renewables.csv")

# %%
df_list=[df,df6,df7,df8,df9,df10,df11,df12,df13,df15,df17]
df_list=functions.drop_code(df_list)

# %%
df_main=functions.specific_merge(df3,df_list)

# %%
list_growth=[df19,df20,df21]
df_growth_list=functions.drop_code(list_growth)
df_growth=functions.specific_merge(df18,list_growth)

# %%
df_main=change_w_values(df_main)

# %%
df_main[df_main['Code'].isna()]
# Out:
# Empty DataFrame
# Columns: [Entity, Code, Year, Solar (% sub energy), Wind (% sub energy), Wind (% electricity), Solar (% electricity), Renewables (% electricity), Hydro (% electricity), Renewables (% sub energy), Renewables per capita (kWh - equivalent), Electricity from wind (TWh), Electricity from hydro (TWh), Electricity from solar (TWh), Electricity from other renewables including bioenergy (TWh), Wind Generation - TWh, Solar Generation - TWh, Geo Biomass Other - TWh, Hydro Generation - TWh, Hydro (% sub energy), Biofuels Production - TWh - Total]
# Index: []
#
# [0 rows x 21 columns]

# %%
def change_main_values(df_main):
    df_main=change_value(df_main,'Entity','World','Code','WRL')
    df_main=change_value(df_main,'Entity','Africa','Code','AFR')

    df_main=change_value(df_main,'Entity','Asia Pacific','Code','ASP')

    df_main=change_value(df_main,'Entity','Eastern Africa','Code','EAF')

    df_main=change_value(df_main,'Entity','European Union (27)','Code','EUU')

    df_main=change_value(df_main,'Entity','Middle Africa','Code','MAF')

    df_main=change_value(df_main,'Entity','Middle Africa','Code','MAF')

    df_main=change_value(df_main,'Entity','Europe','Code','EUR')

    df_main=change_value(df_main,'Entity','Western Africa','Code','WAF')

    df_main=change_value(df_main,'Entity','OECD','Code','OECD')

    df_main=change_value(df_main,'Entity','Middle East','Code','MDLE')

    df_main=change_value(df_main,'Entity','Non-OECD','Code','NOECD')

    df_main=change_value(df_main,'Entity','OECD','Code','OECD')

    df_main = df_main[df_main.Entity != 'CIS']
    return df_main

# %%
change_main_values(df_main)
# Out:
#       Entity Code  Year  Solar (% sub energy)  Wind (% sub energy)  \
# 0     Africa  AFR  1965                 0.000                0.000
# 1     Africa  AFR  1966                 0.000                0.000
# 2     Africa  AFR  1967                 0.000                0.000
# 3     Africa  AFR  1968                 0.000                0.000
# 4     Africa  AFR  1969                 0.000                0.000
# ...      ...  ...   ...                   ...                  ...
# 4830   World  WRL  2016                 0.539                1.579
# 4831   World  WRL  2017                 0.715                1.827
# 4832   World  WRL  2018                 0.896                1.972
# 4833   World  WRL  2019                 1.085                2.174
# 4834   World  WRL  2020                 1.365                2.539
#
#       Wind (% electricity)  Solar (% electricity)  Renewables (% electricity)  \
# 0                      NaN                    NaN                         NaN
# 1                      NaN                    NaN                         NaN
# 2                      NaN                    NaN                         NaN
# 3                      NaN                    NaN                         NaN
# 4                      NaN                    NaN                         NaN
# ...                    ...                    ...                         ...
# 4830                 3.965                  1.358                      24.256
# 4831                 4.570                  1.782                      25.076
# 4832                 4.906                  2.196                      25.763
# 4833                 5.401                  2.642                      26.711
# 4834                 6.079                  3.197                      28.522
#
#       Hydro (% electricity)  Renewables (% sub energy)  ...  \
# 0                       NaN                      5.526  ...
# 1                       NaN                      5.862  ...
# 2                       NaN                      6.069  ...
# 3                       NaN                      6.730  ...
# 4                       NaN                      7.669  ...
# ...                     ...                        ...  ...
# 4830                 16.531                     10.239  ...
# 4831                 16.277                     10.618  ...
# 4832                 16.129                     10.978  ...
# 4833                 16.048                     11.437  ...
# 4834                 16.516                     12.553  ...
#
#       Electricity from wind (TWh)  Electricity from hydro (TWh)  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# ...                           ...                           ...
# 4830                       959.41                       3999.90
# 4831                      1136.94                       4049.15
# 4832                      1268.43                       4170.02
# 4833                      1420.08                       4219.16
# 4834                      1586.94                       4311.81
#
#       Electricity from solar (TWh)  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 4830                        328.48
# 4831                        443.29
# 4832                        567.80
# 4833                        694.50
# 4834                        834.63
#
#       Electricity from other renewables including bioenergy (TWh)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4830                                             581.32
# 4831                                             608.88
# 4832                                             654.58
# 4833                                             688.92
# 4834                                             712.90
#
#       Wind Generation - TWh  Solar Generation - TWh  Geo Biomass Other - TWh  \
# 0                  0.000000                0.000000                 0.000000
# 1                  0.000000                0.000000                 0.000000
# 2                  0.000000                0.000000                 0.000000
# 3                  0.000000                0.000000                 0.000000
# 4                  0.000000                0.000000                 0.000000
# ...                     ...                     ...                      ...
# 4830             962.227395              328.385208               560.681082
# 4831            1140.310949              446.054164               593.790980
# 4832            1269.520536              576.951248               632.173911
# 4833            1418.170046              707.918495               663.134292
# 4834            1591.213512              855.724690               700.068651
#
#       Hydro Generation - TWh  Hydro (% sub energy)  \
# 0                  13.905635                 5.526
# 1                  15.510004                 5.862
# 2                  16.190636                 6.069
# 3                  18.938341                 6.730
# 4                  22.100890                 7.669
# ...                      ...                   ...
# 4830             4018.671591                 6.594
# 4831             4066.718275                 6.515
# 4832             4176.687496                 6.486
# 4833             4227.883280                 6.481
# 4834             4296.802045                 6.856
#
#       Biofuels Production - TWh - Total
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 4830                         927.775210
# 4831                         969.005102
# 4832                        1067.869413
# 4833                        1110.499302
# 4834                        1043.003238
#
# [4779 rows x 21 columns]

# %%
df_growth['Entity']=df_growth['Entity'].str.strip()

# %%
df_growth['Entity'] = df_growth['Entity'].str.replace('\(BP\)','')
df_growth['Entity'] = df_growth['Entity'].str.replace('Other Southern Africa','South Africa')
df_growth['Entity'] = df_growth['Entity'].str.replace('Other South America','South America')
df_growth['Entity'] = df_growth['Entity'].str.replace('Other South and Central America','South and Central America')
df_growth['Entity'] = df_growth['Entity'].str.replace('Other Northern Africa','Northern Africa')
df_growth['Entity'] = df_growth['Entity'].str.replace('Other Middle East','Middle East')
df_growth['Entity'] = df_growth['Entity'].str.replace('Other Europe','Europe')
df_growth['Entity'] = df_growth['Entity'].str.replace('Other Caribbean','Caribbean')
df_growth['Entity'] = df_growth['Entity'].str.replace('Other Africa','Africa')
df_growth['Entity'] = df_growth['Entity'].str.replace('Other Asia Pacific','Asia Pacific')
# Out:
# C:\Users\mataf\AppData\Local\Temp\ipykernel_21128\2042035146.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_growth['Entity'] = df_growth['Entity'].str.replace('\(BP\)','')

# %%
def change_growth_values(df_main):
    df_main=functions.change_value(df_main,'Entity','Africa','Code','AFR')
    
    df_main=functions.change_value(df_main,'Entity','World','Code','WRL')
    
    df_main=functions.change_value(df_main,'Entity','Asia Pacific','Code','ASP')
    df_main=functions.change_value(df_main,'Entity','Eastern Africa','Code','EAF')
    df_main=functions.change_value(df_main,'Entity','European Union (27)','Code','EUU')    
    df_main=functions.change_value(df_main,'Entity','Middle Africa','Code','MAF')
    df_main=functions.change_value(df_main,'Entity','Europe','Code','EUR')
    df_main=functions.change_value(df_main,'Entity','Western Africa','Code','WAF')
    df_main=functions.change_value(df_main,'Entity','OECD','Code','OECD')
    df_main=functions.change_value(df_main,'Entity','Middle East','Code','MDLE')
    df_main=functions.change_value(df_main,'Entity','Non-OECD','Code','NOECD')
    df_main=functions.change_value(df_main,'Entity','OECD','Code','OECD')
    df_main=functions.change_value(df_main,'Entity','Asia','Code','ASIA')
    df_main=functions.change_value(df_main,'Entity','Upper-middle-income countries','Code','MIDC')
    df_main=functions.change_value(df_main,'Entity','Asia Pacific','Code','ASIAP')
    df_main=functions.change_value(df_main,'Entity','South and Central America','Code','LAT')
    df_main=functions.change_value(df_main,'Entity','Central America','Code','CENAM')
    df_main=functions.change_value(df_main,'Entity','South America','Code','SA')
    df_main=functions.change_value(df_main,'Entity','High-income countries','Code','HII')
    df_main=functions.change_value(df_main,'Entity','South America','Code','SA')
    df_main=functions.change_value(df_main,'Entity','South Africa','Code','SAF')
    df_main=functions.change_value(df_main,'Entity','Northern Africa','Code','NAF')
    df_main=functions.change_value(df_main,'Entity','Other South and Central America','Code','SCA')
    df_main=functions.change_value(df_main,'Entity','Lower-middle-income countries','Code','LMC')
    df_main=functions.change_value(df_main,'Entity','Caribbean','Code','CARIB')
    df_main=functions.change_value(df_main,'Entity','North America','Code','NAM')
    df_main=functions.change_value(df_main,'Entity','Oceania','Code','OCE')
    df_main = df_main[df_main.Entity != 'CIS']
    df_main = df_main[df_main.Entity != 'Other CIS']


    return df_main

# %%
df_growth=change_growth_values(df_growth)

# %%
df_growth[df_growth['Code'].isna()]
# Out:
#                Entity Code  Year  Solar (% growth)  Renewables (% growth)  \
# 21            Africa   NaN  2001         25.282646               7.621300
# 22            Africa   NaN  2002         12.297546               5.534923
# 23            Africa   NaN  2003         19.402622              -2.232128
# 24            Africa   NaN  2004         22.471285               6.181133
# 25            Africa   NaN  2005         19.606007               1.388347
# ...               ...  ...   ...               ...                    ...
# 2169  Western Africa   NaN  2017        -22.398472              16.970993
# 2170  Western Africa   NaN  2018         96.081093               7.500041
# 2171  Western Africa   NaN  2019         25.878298              13.357723
# 2172  Western Africa   NaN  2020          3.919840              -0.243151
# 2173  Western Africa   NaN  2021         44.044449               7.132435
#
#       Solar (TWh growth - equivalent)  Renewables (TWh growth - equivalent)
# 21                           0.008640                             15.942383
# 22                           0.005086                             11.043884
# 23                           0.009139                             -7.481918
# 24                           0.012619                             13.666733
# 25                           0.013344                              2.757599
# ...                               ...                                   ...
# 2169                        -0.254691                              7.324181
# 2170                         0.816140                              3.521549
# 2171                         0.425898                              7.208927
# 2172                         0.074361                             -0.382107
# 2173                         0.946973                              4.204906
#
# [512 rows x 7 columns]

# %%
df_main.drop(df_main[(df_main['Year'] <1990)].index,axis=0,inplace=True)

# %%
df_growth.drop(df_growth[(df_growth['Year'] <1990)].index,axis=0,inplace=True)

# %%
df_main = df_main.rename(columns={"Entity": "ENTITY", "Code": "ISO","Year": "YEAR","Solar (% sub energy)": "SOLAR ENERGY %","Wind (% sub energy)": "WIND ENERGY %","Wind (% electricity)": "WIND ELECTRICITY %","Solar (% electricity)": "SOLAR ELECTRICITY %","Renewables (% electricity)": "RENEWABLE ELECTRICITY %","Hydro (% electricity)": "HYDRO ELECTRICITY %","Renewables (% sub energy)": "RENEWABLE ENERGY %","Renewables per capita (kWh - equivalent)": "RENEWABLE PER CAPITA (KWh)","Electricity from wind (TWh)": "WIND ELECTRICITY (TWh)","Electricity from hydro (TWh)": "HYDRO ELECTRICITY (TWh)","Electricity from solar (TWh)": "SOLAR ELECTRICITY (TWh)","Wind Generation - TWh": "WIND GENERATION (TWh)","Solar Generation - TWh": "SOLAR GENERATION (TWh)","Electricity from other renewables including bioenergy (TWh)": "OTHERS RENEWABLE ENERGIES (TWh)","Hydro Generation - TWh": "HYDRO GENERATION (TWh)","Hydro (% sub energy)": "HYDRO ENERGY %"})

# %%
df_main
# Out:
#       ENTITY  ISO  YEAR  SOLAR ENERGY %  WIND ENERGY %  WIND ELECTRICITY %  \
# 25    Africa  AFR  1990           0.000          0.000                 NaN
# 26    Africa  AFR  1991           0.000          0.000                 NaN
# 27    Africa  AFR  1992           0.000          0.000                 NaN
# 28    Africa  AFR  1993           0.000          0.000                 NaN
# 29    Africa  AFR  1994           0.000          0.001                 NaN
# ...      ...  ...   ...             ...            ...                 ...
# 4830   World  WRL  2016           0.539          1.579               3.965
# 4831   World  WRL  2017           0.715          1.827               4.570
# 4832   World  WRL  2018           0.896          1.972               4.906
# 4833   World  WRL  2019           1.085          2.174               5.401
# 4834   World  WRL  2020           1.365          2.539               6.079
#
#       SOLAR ELECTRICITY %  RENEWABLE ELECTRICITY %  HYDRO ELECTRICITY %  \
# 25                    NaN                      NaN                  NaN
# 26                    NaN                      NaN                  NaN
# 27                    NaN                      NaN                  NaN
# 28                    NaN                      NaN                  NaN
# 29                    NaN                      NaN                  NaN
# ...                   ...                      ...                  ...
# 4830                1.358                   24.256               16.531
# 4831                1.782                   25.076               16.277
# 4832                2.196                   25.763               16.129
# 4833                2.642                   26.711               16.048
# 4834                3.197                   28.522               16.516
#
#       RENEWABLE ENERGY %  ...  WIND ELECTRICITY (TWh)  \
# 25                 6.188  ...                     NaN
# 26                 6.569  ...                     NaN
# 27                 6.177  ...                     NaN
# 28                 6.049  ...                     NaN
# 29                 5.931  ...                     NaN
# ...                  ...  ...                     ...
# 4830              10.239  ...                  959.41
# 4831              10.618  ...                 1136.94
# 4832              10.978  ...                 1268.43
# 4833              11.437  ...                 1420.08
# 4834              12.553  ...                 1586.94
#
#       HYDRO ELECTRICITY (TWh)  SOLAR ELECTRICITY (TWh)  \
# 25                        NaN                      NaN
# 26                        NaN                      NaN
# 27                        NaN                      NaN
# 28                        NaN                      NaN
# 29                        NaN                      NaN
# ...                       ...                      ...
# 4830                  3999.90                   328.48
# 4831                  4049.15                   443.29
# 4832                  4170.02                   567.80
# 4833                  4219.16                   694.50
# 4834                  4311.81                   834.63
#
#       OTHERS RENEWABLE ENERGIES (TWh)  WIND GENERATION (TWh)  \
# 25                                NaN               0.000000
# 26                                NaN               0.000000
# 27                                NaN               0.000000
# 28                                NaN               0.002000
# 29                                NaN               0.005400
# ...                               ...                    ...
# 4830                           581.32             962.227395
# 4831                           608.88            1140.310949
# 4832                           654.58            1269.520536
# 4833                           688.92            1418.170046
# 4834                           712.90            1591.213512
#
#       SOLAR GENERATION (TWh)  Geo Biomass Other - TWh  HYDRO GENERATION (TWh)  \
# 25                  0.000000                 0.808000               57.254659
# 26                  0.000000                 0.824000               60.651488
# 27                  0.000000                 0.854250               57.860292
# 28                  0.000000                 0.939700               56.682507
# 29                  0.000000                 0.837000               57.596049
# ...                      ...                      ...                     ...
# 4830              328.385208               560.681082             4018.671591
# 4831              446.054164               593.790980             4066.718275
# 4832              576.951248               632.173911             4176.687496
# 4833              707.918495               663.134292             4227.883280
# 4834              855.724690               700.068651             4296.802045
#
#       HYDRO ENERGY %  Biofuels Production - TWh - Total
# 25             6.102                           0.068617
# 26             6.481                           0.068617
# 27             6.088                           0.068805
# 28             5.951                           0.068617
# 29             5.846                           0.068617
# ...              ...                                ...
# 4830           6.594                         927.775210
# 4831           6.515                         969.005102
# 4832           6.486                        1067.869413
# 4833           6.481                        1110.499302
# 4834           6.856                        1043.003238
#
# [2790 rows x 21 columns]

# %%
df_main.drop(['SOLAR GENERATION (TWh)','WIND GENERATION (TWh)','HYDRO GENERATION (TWh)'],axis=1,inplace=True)

# %%
df_main
# Out:
#       ENTITY  ISO  YEAR  SOLAR ENERGY %  WIND ENERGY %  WIND ELECTRICITY %  \
# 25    Africa  AFR  1990           0.000          0.000                 NaN
# 26    Africa  AFR  1991           0.000          0.000                 NaN
# 27    Africa  AFR  1992           0.000          0.000                 NaN
# 28    Africa  AFR  1993           0.000          0.000                 NaN
# 29    Africa  AFR  1994           0.000          0.001                 NaN
# ...      ...  ...   ...             ...            ...                 ...
# 4830   World  WRL  2016           0.539          1.579               3.965
# 4831   World  WRL  2017           0.715          1.827               4.570
# 4832   World  WRL  2018           0.896          1.972               4.906
# 4833   World  WRL  2019           1.085          2.174               5.401
# 4834   World  WRL  2020           1.365          2.539               6.079
#
#       SOLAR ELECTRICITY %  RENEWABLE ELECTRICITY %  HYDRO ELECTRICITY %  \
# 25                    NaN                      NaN                  NaN
# 26                    NaN                      NaN                  NaN
# 27                    NaN                      NaN                  NaN
# 28                    NaN                      NaN                  NaN
# 29                    NaN                      NaN                  NaN
# ...                   ...                      ...                  ...
# 4830                1.358                   24.256               16.531
# 4831                1.782                   25.076               16.277
# 4832                2.196                   25.763               16.129
# 4833                2.642                   26.711               16.048
# 4834                3.197                   28.522               16.516
#
#       RENEWABLE ENERGY %  RENEWABLE PER CAPITA (KWh)  WIND ELECTRICITY (TWh)  \
# 25                 6.188                    0.272431                     NaN
# 26                 6.569                    0.280890                     NaN
# 27                 6.177                    0.261371                     NaN
# 28                 6.049                    0.250066                     NaN
# 29                 5.931                    0.247196                     NaN
# ...                  ...                         ...                     ...
# 4830              10.239                    2.261189                  959.41
# 4831              10.618                    2.368127                 1136.94
# 4832              10.978                    2.489008                 1268.43
# 4833              11.437                    2.588879                 1420.08
# 4834              12.553                    2.704402                 1586.94
#
#       HYDRO ELECTRICITY (TWh)  SOLAR ELECTRICITY (TWh)  \
# 25                        NaN                      NaN
# 26                        NaN                      NaN
# 27                        NaN                      NaN
# 28                        NaN                      NaN
# 29                        NaN                      NaN
# ...                       ...                      ...
# 4830                  3999.90                   328.48
# 4831                  4049.15                   443.29
# 4832                  4170.02                   567.80
# 4833                  4219.16                   694.50
# 4834                  4311.81                   834.63
#
#       OTHERS RENEWABLE ENERGIES (TWh)  Geo Biomass Other - TWh  \
# 25                                NaN                 0.808000
# 26                                NaN                 0.824000
# 27                                NaN                 0.854250
# 28                                NaN                 0.939700
# 29                                NaN                 0.837000
# ...                               ...                      ...
# 4830                           581.32               560.681082
# 4831                           608.88               593.790980
# 4832                           654.58               632.173911
# 4833                           688.92               663.134292
# 4834                           712.90               700.068651
#
#       HYDRO ENERGY %  Biofuels Production - TWh - Total
# 25             6.102                           0.068617
# 26             6.481                           0.068617
# 27             6.088                           0.068805
# 28             5.951                           0.068617
# 29             5.846                           0.068617
# ...              ...                                ...
# 4830           6.594                         927.775210
# 4831           6.515                         969.005102
# 4832           6.486                        1067.869413
# 4833           6.481                        1110.499302
# 4834           6.856                        1043.003238
#
# [2790 rows x 18 columns]

# %%
df_main
# Out:
#       ENTITY  ISO  YEAR  SOLAR ENERGY %  WIND ENERGY %  WIND ELECTRICITY %  \
# 25    Africa  AFR  1990           0.000          0.000                 NaN
# 26    Africa  AFR  1991           0.000          0.000                 NaN
# 27    Africa  AFR  1992           0.000          0.000                 NaN
# 28    Africa  AFR  1993           0.000          0.000                 NaN
# 29    Africa  AFR  1994           0.000          0.001                 NaN
# ...      ...  ...   ...             ...            ...                 ...
# 4830   World  WRL  2016           0.539          1.579               3.965
# 4831   World  WRL  2017           0.715          1.827               4.570
# 4832   World  WRL  2018           0.896          1.972               4.906
# 4833   World  WRL  2019           1.085          2.174               5.401
# 4834   World  WRL  2020           1.365          2.539               6.079
#
#       SOLAR ELECTRICITY %  RENEWABLE ELECTRICITY %  HYDRO ELECTRICITY %  \
# 25                    NaN                      NaN                  NaN
# 26                    NaN                      NaN                  NaN
# 27                    NaN                      NaN                  NaN
# 28                    NaN                      NaN                  NaN
# 29                    NaN                      NaN                  NaN
# ...                   ...                      ...                  ...
# 4830                1.358                   24.256               16.531
# 4831                1.782                   25.076               16.277
# 4832                2.196                   25.763               16.129
# 4833                2.642                   26.711               16.048
# 4834                3.197                   28.522               16.516
#
#       RENEWABLE ENERGY %  RENEWABLE PER CAPITA (KWh)  WIND ELECTRICITY (TWh)  \
# 25                 6.188                    0.272431                     NaN
# 26                 6.569                    0.280890                     NaN
# 27                 6.177                    0.261371                     NaN
# 28                 6.049                    0.250066                     NaN
# 29                 5.931                    0.247196                     NaN
# ...                  ...                         ...                     ...
# 4830              10.239                    2.261189                  959.41
# 4831              10.618                    2.368127                 1136.94
# 4832              10.978                    2.489008                 1268.43
# 4833              11.437                    2.588879                 1420.08
# 4834              12.553                    2.704402                 1586.94
#
#       HYDRO ELECTRICITY (TWh)  SOLAR ELECTRICITY (TWh)  \
# 25                        NaN                      NaN
# 26                        NaN                      NaN
# 27                        NaN                      NaN
# 28                        NaN                      NaN
# 29                        NaN                      NaN
# ...                       ...                      ...
# 4830                  3999.90                   328.48
# 4831                  4049.15                   443.29
# 4832                  4170.02                   567.80
# 4833                  4219.16                   694.50
# 4834                  4311.81                   834.63
#
#       OTHERS RENEWABLE ENERGIES (TWh)  Geo Biomass Other - TWh  \
# 25                                NaN                 0.808000
# 26                                NaN                 0.824000
# 27                                NaN                 0.854250
# 28                                NaN                 0.939700
# 29                                NaN                 0.837000
# ...                               ...                      ...
# 4830                           581.32               560.681082
# 4831                           608.88               593.790980
# 4832                           654.58               632.173911
# 4833                           688.92               663.134292
# 4834                           712.90               700.068651
#
#       HYDRO ENERGY %  Biofuels Production - TWh - Total
# 25             6.102                           0.068617
# 26             6.481                           0.068617
# 27             6.088                           0.068805
# 28             5.951                           0.068617
# 29             5.846                           0.068617
# ...              ...                                ...
# 4830           6.594                         927.775210
# 4831           6.515                         969.005102
# 4832           6.486                        1067.869413
# 4833           6.481                        1110.499302
# 4834           6.856                        1043.003238
#
# [2790 rows x 18 columns]

# %%
df_main = df_main.reindex(['ENTITY','ISO','YEAR','SOLAR ELECTRICITY (TWh)','SOLAR ENERGY %','WIND ELECTRICITY (TWh)','WIND ENERGY %','WIND ELECTRICITY %','HYDRO ELECTRICITY (TWh)','HYDRO ENERGY %','HYDRO ELECTRICITY %','RENEWABLE ENERGY %','RENEWABLE ELECTRICITY %','RENEWABLE PER CAPITA (KWh)','OTHERS RENEWABLE ENERGIES (TWh)'], axis=1)

# %%
df_growth = df_growth.rename(columns={"Entity": "ENTITY", "Code": "ISO","Year": "YEAR","Solar (% growth)": "SOLAR GROWTH %","Renewables (% growth)": "RENEWABLE GROWTH %","Solar (TWh growth - equivalent)": "SOLAR GROWTH TWh","Renewables (TWh growth - equivalent)": "RENEWABLE GROWTH TWh"})

# %%
df_growth = df_growth.reindex(['ENTITY','ISO','YEAR','SOLAR GROWTH %','SOLAR GROWTH TWh','RENEWABLE GROWTH TWh','RENEWABLE GROWTH %'], axis=1)

# %%
df_main.columns
# Out:
# Index(['ENTITY', 'ISO', 'YEAR', 'SOLAR ELECTRICITY (TWh)', 'SOLAR ENERGY %',
#        'WIND ELECTRICITY (TWh)', 'WIND ENERGY %', 'WIND ELECTRICITY %',
#        'HYDRO ELECTRICITY (TWh)', 'HYDRO ENERGY %', 'HYDRO ELECTRICITY %',
#        'RENEWABLE ENERGY %', 'RENEWABLE ELECTRICITY %',
#        'RENEWABLE PER CAPITA (KWh)', 'OTHERS RENEWABLE ENERGIES (TWh)'],
#       dtype='object')

# %%
df_main
# Out:
#       ENTITY  ISO  YEAR  SOLAR ELECTRICITY (TWh)  SOLAR ENERGY %  \
# 25    Africa  AFR  1990                      NaN           0.000
# 26    Africa  AFR  1991                      NaN           0.000
# 27    Africa  AFR  1992                      NaN           0.000
# 28    Africa  AFR  1993                      NaN           0.000
# 29    Africa  AFR  1994                      NaN           0.000
# ...      ...  ...   ...                      ...             ...
# 4830   World  WRL  2016                   328.48           0.539
# 4831   World  WRL  2017                   443.29           0.715
# 4832   World  WRL  2018                   567.80           0.896
# 4833   World  WRL  2019                   694.50           1.085
# 4834   World  WRL  2020                   834.63           1.365
#
#       WIND ELECTRICITY (TWh)  WIND ENERGY %  WIND ELECTRICITY %  \
# 25                       NaN          0.000                 NaN
# 26                       NaN          0.000                 NaN
# 27                       NaN          0.000                 NaN
# 28                       NaN          0.000                 NaN
# 29                       NaN          0.001                 NaN
# ...                      ...            ...                 ...
# 4830                  959.41          1.579               3.965
# 4831                 1136.94          1.827               4.570
# 4832                 1268.43          1.972               4.906
# 4833                 1420.08          2.174               5.401
# 4834                 1586.94          2.539               6.079
#
#       HYDRO ELECTRICITY (TWh)  HYDRO ENERGY %  HYDRO ELECTRICITY %  \
# 25                        NaN           6.102                  NaN
# 26                        NaN           6.481                  NaN
# 27                        NaN           6.088                  NaN
# 28                        NaN           5.951                  NaN
# 29                        NaN           5.846                  NaN
# ...                       ...             ...                  ...
# 4830                  3999.90           6.594               16.531
# 4831                  4049.15           6.515               16.277
# 4832                  4170.02           6.486               16.129
# 4833                  4219.16           6.481               16.048
# 4834                  4311.81           6.856               16.516
#
#       RENEWABLE ENERGY %  RENEWABLE ELECTRICITY %  RENEWABLE PER CAPITA (KWh)  \
# 25                 6.188                      NaN                    0.272431
# 26                 6.569                      NaN                    0.280890
# 27                 6.177                      NaN                    0.261371
# 28                 6.049                      NaN                    0.250066
# 29                 5.931                      NaN                    0.247196
# ...                  ...                      ...                         ...
# 4830              10.239                   24.256                    2.261189
# 4831              10.618                   25.076                    2.368127
# 4832              10.978                   25.763                    2.489008
# 4833              11.437                   26.711                    2.588879
# 4834              12.553                   28.522                    2.704402
#
#       OTHERS RENEWABLE ENERGIES (TWh)
# 25                                NaN
# 26                                NaN
# 27                                NaN
# 28                                NaN
# 29                                NaN
# ...                               ...
# 4830                           581.32
# 4831                           608.88
# 4832                           654.58
# 4833                           688.92
# 4834                           712.90
#
# [2790 rows x 15 columns]

# %%
df_main
# Out:
#       ENTITY  ISO  YEAR  SOLAR ENERGY %  WIND ENERGY %  WIND ELECTRICITY %  \
# 25    Africa  AFR  1990           0.000          0.000                 NaN
# 26    Africa  AFR  1991           0.000          0.000                 NaN
# 27    Africa  AFR  1992           0.000          0.000                 NaN
# 28    Africa  AFR  1993           0.000          0.000                 NaN
# 29    Africa  AFR  1994           0.000          0.001                 NaN
# ...      ...  ...   ...             ...            ...                 ...
# 4830   World  WRL  2016           0.539          1.579               3.965
# 4831   World  WRL  2017           0.715          1.827               4.570
# 4832   World  WRL  2018           0.896          1.972               4.906
# 4833   World  WRL  2019           1.085          2.174               5.401
# 4834   World  WRL  2020           1.365          2.539               6.079
#
#       SOLAR ELECTRICITY %  RENEWABLE ELECTRICITY %  HYDRO ELECTRICITY %  \
# 25                    NaN                      NaN                  NaN
# 26                    NaN                      NaN                  NaN
# 27                    NaN                      NaN                  NaN
# 28                    NaN                      NaN                  NaN
# 29                    NaN                      NaN                  NaN
# ...                   ...                      ...                  ...
# 4830                1.358                   24.256               16.531
# 4831                1.782                   25.076               16.277
# 4832                2.196                   25.763               16.129
# 4833                2.642                   26.711               16.048
# 4834                3.197                   28.522               16.516
#
#       RENEWABLE ENERGY %  RENEWABLE PER CAPITA KWh  WIND ELECTRICITY TWh  \
# 25                 6.188                  0.272431                   NaN
# 26                 6.569                  0.280890                   NaN
# 27                 6.177                  0.261371                   NaN
# 28                 6.049                  0.250066                   NaN
# 29                 5.931                  0.247196                   NaN
# ...                  ...                       ...                   ...
# 4830              10.239                  2.261189                959.41
# 4831              10.618                  2.368127               1136.94
# 4832              10.978                  2.489008               1268.43
# 4833              11.437                  2.588879               1420.08
# 4834              12.553                  2.704402               1586.94
#
#       HYDRO ELECTRICITY (TWh)  SOLAR ELECTRICITY (TWh)  \
# 25                        NaN                      NaN
# 26                        NaN                      NaN
# 27                        NaN                      NaN
# 28                        NaN                      NaN
# 29                        NaN                      NaN
# ...                       ...                      ...
# 4830                  3999.90                   328.48
# 4831                  4049.15                   443.29
# 4832                  4170.02                   567.80
# 4833                  4219.16                   694.50
# 4834                  4311.81                   834.63
#
#       OTHERS RENEWABLE ENERGIES (TWh)  WIND GENERATION (TWh)  \
# 25                                NaN               0.000000
# 26                                NaN               0.000000
# 27                                NaN               0.000000
# 28                                NaN               0.002000
# 29                                NaN               0.005400
# ...                               ...                    ...
# 4830                           581.32             962.227395
# 4831                           608.88            1140.310949
# 4832                           654.58            1269.520536
# 4833                           688.92            1418.170046
# 4834                           712.90            1591.213512
#
#       SOLAR GENERATION (TWh)  HYDRO GENERATION (TWh)  HYDRO ENERGY %
# 25                  0.000000               57.254659           6.102
# 26                  0.000000               60.651488           6.481
# 27                  0.000000               57.860292           6.088
# 28                  0.000000               56.682507           5.951
# 29                  0.000000               57.596049           5.846
# ...                      ...                     ...             ...
# 4830              328.385208             4018.671591           6.594
# 4831              446.054164             4066.718275           6.515
# 4832              576.951248             4176.687496           6.486
# 4833              707.918495             4227.883280           6.481
# 4834              855.724690             4296.802045           6.856
#
# [2790 rows x 19 columns]

# %%
wrl = df_main.loc[df_main['ENTITY'] == 'World']

# %%
wrl=wrl.reset_index(drop=True)

# %%
wrl.head(10)
# Out:
#   ENTITY  ISO  YEAR  SOLAR ELECTRICITY (TWh)  SOLAR ENERGY %  \
# 0  World  WRL  1990                    0.388           0.001
# 1  World  WRL  1991                    0.505           0.001
# 2  World  WRL  1992                    0.469           0.001
# 3  World  WRL  1993                    0.557           0.002
# 4  World  WRL  1994                    0.600           0.002
# 5  World  WRL  1995                    0.641           0.002
# 6  World  WRL  1996                    0.705           0.002
# 7  World  WRL  1997                    0.757           0.002
# 8  World  WRL  1998                    0.832           0.002
# 9  World  WRL  1999                    0.916           0.002
#
#    WIND ELECTRICITY (TWh)  WIND ENERGY %  WIND ELECTRICITY %  \
# 0                   3.632          0.011               0.030
# 1                   4.087          0.012               0.033
# 2                   4.733          0.014               0.038
# 3                   5.698          0.016               0.045
# 4                   7.123          0.020               0.055
# 5                   8.262          0.023               0.062
# 6                   9.205          0.025               0.067
# 7                  12.018          0.032               0.085
# 8                  15.921          0.042               0.110
# 9                  21.216          0.055               0.142
#
#    HYDRO ELECTRICITY (TWh)  HYDRO ENERGY %  HYDRO ELECTRICITY %  \
# 0                 2158.906           6.310               18.055
# 1                 2209.410           6.411               18.083
# 2                 2209.074           6.368               17.917
# 3                 2341.245           6.699               18.594
# 4                 2356.882           6.656               18.247
# 5                 2485.633           6.869               18.584
# 6                 2520.499           6.771               18.279
# 7                 2566.135           6.826               18.173
# 8                 2586.942           6.842               17.837
# 9                 2605.676           6.771               17.467
#
#    RENEWABLE ENERGY %  RENEWABLE ELECTRICITY %  RENEWABLE PER CAPITA (KWh)  \
# 0               6.770                   19.067                    1.287152
# 1               6.890                   19.119                    1.298259
# 2               6.869                   19.021                    1.283011
# 3               7.216                   19.718                    1.338271
# 4               7.195                   19.394                    1.331868
# 5               7.421                   19.745                    1.383799
# 6               7.317                   19.442                    1.383306
# 7               7.407                   19.406                    1.394515
# 8               7.453                   19.117                    1.391601
# 9               7.409                   18.804                    1.390053
#
#    OTHERS RENEWABLE ENERGIES (TWh)
# 0                          117.003
# 1                          122.019
# 2                          130.972
# 3                          135.306
# 4                          140.426
# 5                          146.362
# 6                          150.566
# 7                          161.287
# 8                          168.762
# 9                          177.393

# %%
import pycountry_convert as pc

# %%
df_main['ENTITY']
# Out:
# 25      Africa
# 26      Africa
# 27      Africa
# 28      Africa
# 29      Africa
#          ...
# 4830     World
# 4831     World
# 4832     World
# 4833     World
# 4834     World
# Name: ENTITY, Length: 2790, dtype: object

# %%
cou_list=['Africa', 'Asia Pacific', 'Eastern Africa', 'European Union (27)','Europe', 'Middle Africa', 'Middle East' ,'Non-OECD', 'OECD', 'Western Africa','World']
for i in cou_list:
    df_main.drop(df_main[(df_main['ENTITY'] == i)].index,axis=0,inplace=True)

# %%
df_main['ENTITY'].unique()
# Out:
# array(['Algeria', 'Argentina', 'Australia', 'Austria', 'Azerbaijan',
#        'Bangladesh', 'Belarus', 'Belgium', 'Brazil', 'Bulgaria', 'Canada',
#        'Chile', 'China', 'Colombia', 'Croatia', 'Cyprus', 'Czechia',
#        'Denmark', 'Ecuador', 'Egypt', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy', 'Japan',
#        'Kazakhstan', 'Kuwait', 'Latvia', 'Lithuania', 'Luxembourg',
#        'Malaysia', 'Mexico', 'Morocco', 'Netherlands', 'New Zealand',
#        'North Macedonia', 'Norway', 'Oman', 'Pakistan', 'Peru',
#        'Philippines', 'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia',
#        'Saudi Arabia', 'Singapore', 'Slovakia', 'Slovenia',
#        'South Africa', 'South Korea', 'Spain', 'Sri Lanka', 'Sweden',
#        'Switzerland', 'Taiwan', 'Thailand', 'Trinidad and Tobago',
#        'Turkey', 'Turkmenistan', 'Ukraine', 'United Arab Emirates',
#        'United Kingdom', 'United States', 'Uzbekistan', 'Venezuela',
#        'Vietnam'], dtype=object)

# %%
def convert(row):
    cn_code= pc.country_name_to_country_alpha2(row.ENTITY,cn_name_format='default')
    conti_code=pc.country_alpha2_to_continent_code(cn_code)
    return conti_code

# %%
df_main['CONTINENT']=df_main.apply(convert,axis=1)

# %%
continents = {
    'NA': 'North America',
    'SA': 'South America', 
    'AS': 'Asia',
    'OC': 'Australia',
    'AF': 'Africa',
    'EU': 'Europe'
}
df_main['CONTINENT']=df_main['CONTINENT'].map(continents)

# %%
df_main['CONTINENT']=df_main.CONTINENT.str.upper()

# %%
df_main.columns
# Out:
# Index(['ENTITY', 'ISO', 'YEAR', 'SOLAR ELECTRICITY (TWh)', 'SOLAR ENERGY %',
#        'WIND ELECTRICITY (TWh)', 'WIND ENERGY %', 'WIND ELECTRICITY %',
#        'HYDRO ELECTRICITY (TWh)', 'HYDRO ENERGY %', 'HYDRO ELECTRICITY %',
#        'RENEWABLE ENERGY %', 'RENEWABLE ELECTRICITY %',
#        'RENEWABLE PER CAPITA (KWh)', 'OTHERS RENEWABLE ENERGIES (TWh)',
#        'CONTINENT'],
#       dtype='object')

# %%
df_main = df_main.reindex(['ENTITY','ISO','CONTINENT','YEAR','SOLAR ELECTRICITY (TWh)','SOLAR ENERGY %','WIND ELECTRICITY (TWh)','WIND ENERGY %','WIND ELECTRICITY %','HYDRO ELECTRICITY (TWh)','HYDRO ENERGY %','HYDRO ELECTRICITY %','RENEWABLE ENERGY %','RENEWABLE ELECTRICITY %','RENEWABLE PER CAPITA (KWh)','OTHERS RENEWABLE ENERGIES (TWh)'], axis=1)

# %%
df_main.sample(50)
# Out:
#                ENTITY  ISO      CONTINENT  YEAR  SOLAR ELECTRICITY (TWh)  \
# 3215             Peru  PER  SOUTH AMERICA  1996                     0.00
# 4069      Switzerland  CHE         EUROPE  1999                     0.01
# 4310           Turkey  TUR           ASIA  2016                     1.04
# 2247            Japan  JPN           ASIA  2007                     2.02
# 1303          Estonia  EST         EUROPE  2015                     0.00
# 923           Croatia  HRV         EUROPE  2007                     0.00
# 97            Algeria  DZA         AFRICA  2006                     0.00
# 249         Australia  AUS      AUSTRALIA  1990                     0.00
# 4510   United Kingdom  GBR         EUROPE  2012                     1.35
# 501           Belgium  BEL         EUROPE  2008                     0.04
# 2957  North Macedonia  MKD         EUROPE  2018                     0.02
# 1903        Indonesia  IDN           ASIA  1999                     0.00
# 611          Bulgaria  BGR         EUROPE  2006                     0.00
# 553            Brazil  BRA  SOUTH AMERICA  2004                     0.00
# 3864      South Korea  KOR           ASIA  2018                     9.21
# 930           Croatia  HRV         EUROPE  2014                     0.04
# 3610     Saudi Arabia  SAU           ASIA  2019                     1.04
# 1732          Hungary  HUN         EUROPE  1996                     0.00
# 1864            India  IND           ASIA  2016                    11.56
# 4347     Turkmenistan  TKM           ASIA  2017                     0.00
# 1634           Greece  GRC         EUROPE  2010                     0.16
# 1102          Denmark  DNK         EUROPE  2018                     0.95
# 1299          Estonia  EST         EUROPE  2011                     0.00
# 2083          Ireland  IRL         EUROPE  2011                     0.00
# 3528           Russia  RUS         EUROPE  1993                     0.00
# 454           Belarus  BLR         EUROPE  2017                     0.09
# 919           Croatia  HRV         EUROPE  2003                     0.00
# 2032             Iraq  IRQ           ASIA  2016                     0.06
# 2290       Kazakhstan  KAZ           ASIA  2014                     0.00
# 2742          Morocco  MAR         AFRICA  2002                     0.00
# 138         Argentina  ARG  SOUTH AMERICA  1991                     0.00
# 719            Canada  CAN  NORTH AMERICA  2002                     0.02
# 2386           Latvia  LVA         EUROPE  2018                     0.00
# 103           Algeria  DZA         AFRICA  2012                     0.00
# 491           Belgium  BEL         EUROPE  1998                     0.00
# 3967        Sri Lanka  LKA           ASIA  2009                     0.02
# 601          Bulgaria  BGR         EUROPE  1996                     0.00
# 2186            Italy  ITA         EUROPE  2002                     0.02
# 1558          Germany  DEU         EUROPE  1990                     0.00
# 2530         Malaysia  MYS           ASIA  2014                     0.23
# 921           Croatia  HRV         EUROPE  2005                     0.00
# 2453       Luxembourg  LUX         EUROPE  1993                     0.00
# 3001           Norway  NOR         EUROPE  2006                     0.00
# 785             Chile  CHL  SOUTH AMERICA  2012                     0.00
# 416        Bangladesh  BGD           ASIA  2015                     0.21
# 4083      Switzerland  CHE         EUROPE  2013                     0.50
# 1746          Hungary  HUN         EUROPE  2010                     0.00
# 1216          Ecuador  ECU  SOUTH AMERICA  2020                     0.04
# 3721         Slovakia  SVK         EUROPE  2018                     0.58
# 2858      New Zealand  NZL      AUSTRALIA  2006                     0.00
#
#       SOLAR ENERGY %  WIND ELECTRICITY (TWh)  WIND ENERGY %  \
# 3215           0.000                   0.000          0.001
# 4069           0.008                   0.003          0.002
# 4310           0.157                  15.520          2.337
# 2247           0.100                   2.610          0.119
# 1303           0.021                   0.710          2.574
# 923            0.000                   0.030          0.086
# 97             0.000                   0.000          0.000
# 249            0.000                   0.000          0.000
# 4510           0.147                  19.850          2.159
# 501            0.014                   0.640          0.218
# 2957           0.195                   0.100          0.833
# 1903           0.000                   0.000          0.000
# 611            0.000                   0.020          0.022
# 553            0.000                   0.060          0.007
# 3864           0.663                   2.460          0.177
# 930            0.094                   0.730          1.970
# 3610           0.087                   0.000          0.000
# 1732           0.000                   0.000          0.000
# 1864           0.349                  43.450          1.313
# 4347           0.005                   0.000          0.000
# 1634           0.111                   2.710          1.900
# 1102           1.223                  13.900         17.839
# 1299           0.001                   0.370          1.296
# 2083           0.001                   4.380          6.723
# 3528           0.000                   0.000          0.000
# 454            0.081                   0.100          0.089
# 919            0.000                   0.000          0.000
# 2032           0.027                   0.000          0.000
# 2290           0.000                   0.010          0.004
# 2742           0.000                   0.190          0.409
# 138            0.000                   0.000          0.000
# 719            0.002                   0.410          0.031
# 2386           0.007                   0.120          0.700
# 103            0.014                   0.000          0.000
# 491            0.000                   0.010          0.004
# 3967           0.029                   0.000          0.015
# 601            0.000                   0.000          0.000
# 2186           0.003                   1.400          0.186
# 1558           0.000                   0.070          0.005
# 2530           0.053                   0.000          0.000
# 921            0.000                   0.010          0.025
# 2453           0.000                   0.000          0.000
# 3001           0.004                   0.640          0.345
# 785            0.000                   0.410          0.256
# 416            0.138                   0.010          0.004
# 4083           0.365                   0.090          0.066
# 1746           0.001                   0.530          0.499
# 1216           0.229                   0.080          0.118
# 3721           0.771                   0.010          0.008
# 2858           0.000                   0.620          0.738
#
#       WIND ELECTRICITY %  HYDRO ELECTRICITY (TWh)  HYDRO ENERGY %  \
# 3215               0.002                   13.324          27.216
# 4069               0.004                   40.008          30.492
# 4310               5.671                   67.230          10.126
# 2247               0.236                   73.270           3.222
# 1303               6.995                    0.030           0.097
# 923                0.239                    4.700          11.598
# 97                 0.000                    0.220           0.153
# 249                0.000                   14.760           3.980
# 4510               5.500                    5.310           0.577
# 501                0.773                    0.410           0.140
# 2957               1.783                    1.790          15.323
# 1903               0.000                   10.380           2.649
# 611                0.044                    4.210           4.696
# 553                0.016                  317.590          36.353
# 3864               0.444                    3.320           0.242
# 930                5.432                    9.010          24.307
# 3610               0.000                    0.000           0.000
# 1732               0.000                    0.210           0.197
# 1864               3.100                  128.380           3.880
# 4347               0.000                    0.000           0.002
# 1634               4.723                    7.470           5.223
# 1102              45.784                    0.010           0.019
# 1299               2.870                    0.030           0.106
# 2083              16.127                    0.710           1.084
# 3528               0.000                  174.289           5.452
# 454                0.308                    0.400           0.372
# 919                0.000                    5.460          14.113
# 2032               0.000                    3.340           1.579
# 2290               0.011                    8.260           2.777
# 2742               1.253                    0.840           1.778
# 138                0.000                   16.221           8.684
# 719                0.070                  347.050          26.437
# 2386               1.786                    2.430          13.956
# 103                0.000                    0.620           0.197
# 491                0.012                    0.390           0.148
# 3967               0.000                    3.870          16.667
# 601                0.000                    2.890           3.015
# 2186               0.506                   39.520           5.223
# 1558               0.013                   17.430           1.152
# 2530               0.000                   13.400           3.113
# 921                0.077                    7.040          17.515
# 2453               0.000                    0.070           0.459
# 3001               0.529                  119.370          64.765
# 785                0.613                   19.980          12.662
# 416                0.018                    0.590           0.625
# 4083               0.134                   38.080          28.046
# 1746               1.418                    0.190           0.178
# 1216               0.256                   24.790          34.097
# 3721               0.038                    3.590           4.734
# 2858               1.461                   23.340          27.950
#
#       HYDRO ELECTRICITY %  RENEWABLE ENERGY %  RENEWABLE ELECTRICITY %  \
# 3215               77.105              27.497                   77.900
# 4069               58.306              31.073                   59.417
# 4310               24.564              13.593                   32.972
# 2247                6.638               4.401                   11.090
# 1303                0.296               5.496                   15.369
# 923                37.480              11.702                   37.799
# 97                  0.664               0.153                    0.664
# 249                 9.482               4.185                    9.970
# 4510                1.471               4.924                   11.427
# 501                 0.495               1.512                    5.338
# 2957               31.907              16.813                   34.938
# 1903               12.361               3.655                   17.054
# 611                 9.257               4.718                    9.301
# 553                83.320              40.814                   86.426
# 3864                0.599               2.428                    5.720
# 930                67.039              26.817                   73.958
# 3610                0.000               0.087                    0.302
# 1732                0.598               0.245                    0.741
# 1864                9.159               6.501                   14.855
# 4347                0.000               0.008                    0.000
# 1634               13.018               7.367                   18.351
# 1102                0.033              26.832                   68.347
# 1299                0.233               4.161                    9.154
# 2083                2.614               8.324                   19.993
# 3528               18.220               5.453                   18.226
# 454                 1.231               0.639                    2.278
# 919                41.395              14.113                   41.395
# 2032                4.426               1.606                    4.506
# 2290                8.728               2.781                    8.746
# 2742                5.541               2.187                    6.794
# 138                30.120               8.738                   30.305
# 719                59.433              27.272                   61.148
# 2386               36.161              20.080                   51.935
# 103                 1.148               0.211                    1.148
# 491                 0.475               0.288                    0.926
# 3967               40.271              16.810                   41.103
# 601                 6.771               3.015                    6.771
# 2186               14.280               6.386                   17.456
# 1558                3.188               1.252                    3.493
# 2530                9.606               3.327                   10.237
# 921                53.905              17.575                   54.058
# 2453               10.448               0.560                   11.940
# 3001               98.580              65.324                   99.430
# 785                29.861              16.677                   35.226
# 416                 1.061               0.769                    1.511
# 4083               56.709              29.648                   57.870
# 1746                0.508               2.853                    8.081
# 1216               79.277              35.111                   83.786
# 3721               13.511               7.657                   21.867
# 2858               54.995              33.299                   67.130
#
#       RENEWABLE PER CAPITA (KWh)  OTHERS RENEWABLE ENERGIES (TWh)
# 3215                    1.609297                            0.137
# 4069                   16.968777                            0.749
# 4310                    3.059842                            6.450
# 2247                    2.290960                           44.520
# 1303                    3.422009                            0.820
# 923                     3.074233                            0.010
# 97                      0.018405                            0.000
# 249                     2.716187                            0.760
# 4510                    2.016270                           14.730
# 501                     1.269812                            3.330
# 2957                    2.510772                            0.050
# 1903                    0.200732                            3.941
# 611                     1.587695                            0.000
# 553                     5.635999                           11.780
# 3864                    1.889536                           16.700
# 930                     6.344708                            0.160
# 3610                    0.015902                            0.000
# 1732                    0.074688                            0.050
# 1864                    0.443540                           24.817
# 4347                    0.004675                            0.000
# 1634                    2.689637                            0.190
# 1102                   10.108215                            5.890
# 1299                    2.709943                            0.780
# 2083                    3.291104                            0.340
# 3528                    3.474691                            0.060
# 454                     0.202520                            0.150
# 919                     3.606563                            0.000
# 2032                    0.250701                            0.000
# 2290                    1.295995                            0.000
# 2742                    0.102663                            0.000
# 138                     1.431223                            0.100
# 719                    33.816398                            9.580
# 2386                    5.067273                            0.940
# 103                     0.030491                            0.000
# 491                     0.227482                            0.360
# 3967                    0.545080                            0.060
# 601                     1.040941                            0.000
# 2186                    2.469591                            7.370
# 1558                    0.709048                            1.600
# 2530                    1.309039                            0.650
# 921                     4.618547                            0.010
# 2453                    0.617627                            0.010
# 3001                   73.341023                            0.390
# 785                     4.339173                            3.180
# 416                     0.019040                            0.030
# 4083                   13.759033                            0.190
# 1746                    0.938798                            2.300
# 1216                    3.724411                            1.290
# 3721                    2.979837                            1.630
# 2858                   19.183223                            4.530

# %%
import pymysql
import sqlalchemy as alch

# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv()
password= os.getenv("password")
password
# Out:
# 'Askatasuna7'

# %%
dbName = "final_project"

connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"

engine = alch.create_engine(connectionData)
engine

df_main.to_sql("renewable", if_exists="replace", index=False,con=engine)
# Out:
# 2790

# %%
df_growth.to_sql("growth", if_exists="replace",index=False, con=engine)
# Out:
# 2164

# %% [markdown]
# # Viz

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#sns.pairplot(df_train,y_vars=['price'], x_vars=['carat','depth', 'table', 'x', 'y', 'z',
      # 'price']);

# %%
sns.set_context("poster")
sns.set(rc={"figure.figsize": (15.,5.)})
sns.set_style("whitegrid")

# %%
sns.barplot(data=wrl,x='YEAR',y='SOLAR ELECTRICITY (TWh)');
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='SOLAR ELECTRICITY (TWh)'>

# %%
sns.barplot(data=wrl,x='YEAR',y='WIND ELECTRICITY (TWh)');

# %%
sns.barplot(data=wrl,x='YEAR',y='HYDRO ELECTRICITY (TWh)');

# %%
sns.barplot(data=wrl,x='YEAR',y='WIND ELECTRICITY TWh');

# %%
sns.barplot(data=wrl,x='YEAR',y='RENEWABLE ELECTRICITY %');

# %%
wrl.columns
# Out:
# Index(['ENTITY', 'ISO', 'YEAR', 'SOLAR ELECTRICITY (TWh)', 'SOLAR ENERGY %',
#        'WIND ELECTRICITY (TWh)', 'WIND ENERGY %', 'WIND ELECTRICITY %',
#        'HYDRO ELECTRICITY (TWh)', 'HYDRO ENERGY %', 'HYDRO ELECTRICITY %',
#        'RENEWABLE ENERGY %', 'RENEWABLE ELECTRICITY %',
#        'RENEWABLE PER CAPITA KWh', 'OTHERS RENEWABLE ENERGIES (TWh)'],
#       dtype='object')

# %%
sns.barplot(data=wrl,x='YEAR',y='OTHERS RENEWABLE ENERGIES (TWh)');

# %%
sns.barplot(data=wrl,x='YEAR',y='RENEWABLE PER CAPITA (KWh)');

# %%
sns.barplot(data=wrl,x='YEAR',y='OTHERS RENEWABLE ENERGIES (TWh)');

# %%
sns.barplot(data=wrl,x='YEAR',y='SOLAR GENERATION (TWh)');

# %%
sns.barplot(data=wrl,x='YEAR',y='SOLAR GENERATION (TWh)');
